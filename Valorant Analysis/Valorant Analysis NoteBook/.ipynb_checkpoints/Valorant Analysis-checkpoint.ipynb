# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn  as sb

# %%
data=pd.read_csv("C:/Users/LITE/Documents/Valorant Analysis/Lite.csv")

# %%
data.head()
# Out:
#                             Date  Map Name Match Result Agent Name  kills  \
# 0  2021-11-08T15:49:57.865-05:00    Icebox       defeat       Jett      5
# 1  2021-11-07T17:06:44.201-05:00  Fracture      victory    Killjoy     12
# 2  2021-11-07T16:28:18.946-05:00    Breeze       defeat       Yoru      3
# 3  2021-11-07T15:32:01.224-05:00     Haven      victory       Jett     11
# 4  2021-11-07T13:40:04.085-05:00    Ascent       defeat     Breach     15
#
#    headshots  deaths  assists  damage  damageReceived  plants  defuses  \
# 0          1      14        3    1327            2447       0        0
# 1          5       9        1    2169            1871       9        0
# 2          1      17        2     895            3077       0        0
# 3          6      19        6    2685            3633       1        0
# 4          8      20        3    2925            3671       0        0
#
#    firstBloods   kdRatio  placement      rank
# 0            0  0.357143          9  Silver 1
# 1            2  1.333333          7  Silver 1
# 2            1  0.176471          9  Silver 1
# 3            0  0.578947          9  Silver 1
# 4            1  0.750000          4  Silver 1

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# In this part, I'll divide the date column into two colmun into datetime and hour.

# %%
hour=[]
for i in range(len(data['Date'])):
    hour.append(data['Date'][i].split('T')[1].split('.')[0])
data.insert(1,'hour',hour)    


day=pd.to_datetime(data['Date'])
for i in range(len(day)):
    day[i]=day[i].date()  
data['Date']=day

# %%
data.head()
# Out:
#          Date      hour  Map Name Match Result Agent Name  kills  headshots  \
# 0  2021-11-08  15:49:57    Icebox       defeat       Jett      5          1
# 1  2021-11-07  17:06:44  Fracture      victory    Killjoy     12          5
# 2  2021-11-07  16:28:18    Breeze       defeat       Yoru      3          1
# 3  2021-11-07  15:32:01     Haven      victory       Jett     11          6
# 4  2021-11-07  13:40:04    Ascent       defeat     Breach     15          8
#
#    deaths  assists  damage  damageReceived  plants  defuses  firstBloods  \
# 0      14        3    1327            2447       0        0            0
# 1       9        1    2169            1871       9        0            2
# 2      17        2     895            3077       0        0            1
# 3      19        6    2685            3633       1        0            0
# 4      20        3    2925            3671       0        0            1
#
#     kdRatio  placement      rank
# 0  0.357143          9  Silver 1
# 1  1.333333          7  Silver 1
# 2  0.176471          9  Silver 1
# 3  0.578947          9  Silver 1
# 4  0.750000          4  Silver 1

# %% [markdown]
# ### Data Visualisation

# %% [markdown]
# #### Top Agent kills

# %%
agent_kills=data[['Agent Name','kills']]
agent_kills=agent_kills.set_index('Agent Name')
agent_kills=agent_kills.groupby(['Agent Name']).sum()
agent_kills=agent_kills.sort_values(by=['kills'],ascending=False)
agent_kills=agent_kills.head()
agent_kills
# Out:
#             kills
# Agent Name
# Omen          383
# Sage          375
# Cypher        327
# Jett          188
# Phoenix       187

# %%
sb.set_theme(style="whitegrid")
ax = sb.barplot(x=agent_kills.index, y=agent_kills['kills'], data=agent_kills)

# %% [markdown]
# ### Best Agent performance

# %%
agent_ADR=data[['Agent Name','kdRatio']]
agent_ADR=agent_kills.set_index('Agent Name')
agent_ADR=agent_kills.groupby(['Agent Name']).sum()
agent_ADR=agent_kills.sort_values(by=['kdRatio'],ascending=False)
agent_ADR=agent_kills.head()
agent_ADR

# %%
agent_ADR=data[['Agent Name']]
agent_ADR.groupby(agent_ADR['Agent Name'].tolist()).size().reset_index().\
    rename(columns={0:'records'})
# agent_ADR=agent_ADR.groupby(['Agent Name']).count()
agent_ADR
# Out:
# Empty DataFrame
# Columns: []
# Index: [Breach, Cypher, Jett, Killjoy, Omen, Phoenix, Reyna, Sage, Skye, Sova, Yoru]

# %%
data['Match '].replace(to_replace=['defeat', 'victory'], value=[0, 1])
